# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenkumar753/FMML-Assignments/blob/main/Module_8_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 10:01:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   187MB/s    in 0.4s
#
# 2023-05-03 10:01:10 (187 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11811  1702.02267v4  We consider the problem of reconstructing a ra...  stat
# 21588   1106.0474v1  We propose a restricted collapsed draw (RCD) s...  stat
# 34302  1508.01577v2  Can artificial communities of agents develop l...    cs
# 22166  1506.03958v1  Over the past years Robust PCA has been establ...  stat
# 30596  1712.07262v1  Recent deep networks that directly handle poin...    cs
# ...             ...                                                ...   ...
# 21988   1307.8333v1  In this project we further investigate the ide...  stat
# 6696   1705.06412v2  We consider the problem of recovering a signal...  stat
# 14869   1210.8440v1  Large language models have been proven quite b...    cs
# 28063  1705.05273v3  Template-based model-free approach provides by...    cs
# 8711   1801.01451v1  We propose a novel way that uses shallow dense...    cs
#
#                                                    title  year  \
# 11811  Matrix Completion from $O(n)$ Samples in Linea...  2017
# 21588  Restricted Collapsed Draw: Accurate Sampling f...  2011
# 34302  Automata networks model for alignment and leas...  2015
# 22166  Robust Structured Low-Rank Approximation on th...  2015
# 30596  FoldingNet: Interpretable Unsupervised Learnin...  2017
# ...                                                  ...   ...
# 21988  Borel Isomorphic Dimensionality Reduction of D...  2013
# 6696   Sample-Efficient Algorithms for Recovering Str...  2017
# 14869  Large Scale Language Modeling in Automatic Spe...  2012
# 28063  View-invariant Gait Recognition through Geneti...  2017
# 8711   Reducing Deep Network Complexity with Fourier ...  2017
#
#                                                 keywords
# 11811  [reconstructing, incoherence, assumption, cond...
# 21588  [restricted, collapsed, simultaneous, hierarch...
# 34302  [artificial, communities, relations, prelimina...
# 22166  [established, approximation, minimization, str...
# 30596  [supervised, classification, segmentation, uns...
# ...                                                  ...
# 21988  [investigate, dimensionality, isomorphism, sub...
# 6696   [recovering, magnitude, measurements, |leftlan...
# 14869  [beneficial, automatic, recognition, summarize...
# 28063  [successful, recognition, literature, discusse...
# 8711   [connected, architectures, performance, convol...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11811    [reconstructing, incoherence, assumption, cond...
# 21588    [restricted, collapsed, simultaneous, hierarch...
# 34302    [artificial, communities, relations, prelimina...
# 22166    [established, approximation, minimization, str...
# 30596    [supervised, classification, segmentation, uns...
#                                ...
# 14970    [unsupervised, adaptation, performed, incremen...
# 22533    [exploiting, processes, behaviour, procedure, ...
# 21478    [recognition, sequences, libraries, approaches...
# 13132    [graphical, essential, inference, configuratio...
# 32737    [introduce, generalization, difference, interr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8815 words.
# Out of those 4582 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6867f78d-7f85-45d1-b339-c1da24ecb2be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6867f78d-7f85-45d1-b339-c1da24ecb2be")) {                    Plotly.newPlot(                        "6867f78d-7f85-45d1-b339-c1da24ecb2be",                        [{"x":["structure","regularization","algorithm","frobenius","application","reconstructing","approximation","bipartite","thresholding","minimization","incoherence","condition","conditions","independent","rescaling","computational","recovered","complexity","controlling","approximately","alternating","assumption","completion","hierarchical","efficiency","combination","experiments","arrangements","outperformed","sophisticated","algorithms","stochastically","restricted","simultaneous","conventional","difficult","constructing","restriction","metropolis","calculating","restaurant","developed","distributions","retaining","dirichlet","explosion","combinatorial","collapsed","representation","including","vocabularies","agreement","individuals","principle","emergence","linguistic","strategies","alignment","vocabulary","simulations","essentially","population","relations","conventions","communities","artificial","numerical","preliminary","dimensional","formation","communicative","languages","minimizes","identification","structures","robustness","simulated","established","grassmannian","drawbacks","forecasting","processing","initialization","evaluated","approaches","manifolds","structured","applications","factorization","underlying","architecture","reconstruction","arbitrary","discriminative","supervised","interpretable","reconstruct","challenges","connected","segmentation","unsupervised","enhancement","parameters","benchmark","classification","committee","interaction","inferring","arguments","primarily","generative","performance","evolution","capabilities","relationships","uncovering","demonstrating","discussions","multivariate","inference","discovers","influence","transcripts","extensive","coreference","different","resolution","improving","outperforms","embeddings","anaphoric","detecting","generalized","representations","discrepancy","important","facilitates","predicting","inpatient","medication","pharmacological","investigate","discharge","predictions","convolutional","technologies","physicians","demonstrate","information","documented","admission","unstructured","correlations","capturing","baselines","detection","available","procedure","represented","illustrated","implemented","microstructure","introduced","observation","frequency","simulation","estimation","estimator","estimated","multiscale","integrated","correlated","volatility","correction","simultaneously","geometries","searching","technique","estimating","optimizing","performed","representing","variability","stationarity","proposing","likelihood","importance","constrain","challenging","parametric","quantitative","qualitative","misleading","tailoring","aesthetics","behaviours","paintings","cooperation","mechanisms","intelligence"],"y":[358,79,780,2,232,16,126,5,15,60,2,42,136,137,0,271,8,232,16,22,28,67,32,103,134,128,630,4,15,37,612,1,47,24,106,155,49,10,5,14,4,198,130,16,19,6,32,1,390,234,7,21,32,51,18,86,97,48,33,40,26,53,102,4,24,152,75,47,180,18,6,104,18,109,141,93,66,47,1,9,13,297,24,112,446,19,118,418,33,121,248,108,84,106,210,28,39,131,83,188,143,21,239,209,505,3,76,22,20,22,143,882,58,46,70,3,26,9,21,226,12,50,4,179,8,754,134,111,281,66,3,87,65,223,16,356,15,70,1,2,1,146,1,86,383,29,6,607,693,5,2,20,38,40,61,326,300,94,83,18,92,2,136,66,60,99,203,21,54,15,56,32,6,22,106,4,29,229,66,43,131,78,25,4,24,65,86,11,274,39,67,50,2,5,7,7,6,12,45,94],"type":"bar"},{"x":["structure","regularization","algorithm","frobenius","application","reconstruct ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4582,), (4582, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Genetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Hyperloop</span> <span style=''>route</span> <span style=''>through</span> <span style=''>the</span> <span style=''>Grapevine</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>a</span> <span style=''>genetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>employs</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>versatile</span> <span style=''>fitness</span> <span style=''>function</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>route</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Hyperloop</span> <span style=''>a</span> <span style=''>proposed</span> <span style=''>high</span> <span style=''>speed</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>passenger</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transportation</span> <span style=''>system</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Mean</span> <span style=''>Field</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Gradient</span> <span style=''>Matching</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Gradient</span> <span style=''>matching</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>ordinary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>(ODEs)</span> <span style=''>The</span> <span style=''>essence</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>matching</span> <span style=''>is</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>over</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>which</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>given</span> <span style=''>the</span> <span style=''>ODEs</span> <span style=''>and</span> <span style=''>GP</span> <span style=''>kernels</span> <span style=''>is</span> <span style=''>also</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>The</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivatives</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style=''>out</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style=''>since</span> <span style=''>they</span> <span style=''>are</span> <span style=''>modelled</span> <span style=''>as</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>However</span> <span style=''>the</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>themselves</span> <span style=''>are</span> <span style=''>also</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>because</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contaminated</span> <span style=''>by</span> <span style=''>noise</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>sampled</span> <span style=''>the</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>since</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrating</span> <span style=''>them</span> <span style=''>out</span> <span style=''>is</span> <span style=''>textitnot</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>use</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>Exchangeable</span> <span style=''>Variable</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3133640552995392);'>variables</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>exchangeable</span> <span style=''>if</span> <span style=''>its</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>invariant</span> <span style=''>under</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>exchangeable</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>(EVMs)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>whose</span> <span style=''>basic</span> <span style=''>building</span> <span style=''>blocks</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>exchangeable</span> <span style='background-color:rgba(0, 255, 0, 0.368421052631579);'>sequences</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636365);'>exchangeable</span> <span style='background-color:rgba(0, 255, 0, 0.368421052631579);'>sequences</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>EVMs</span> <span style=''>is</span> <span style=''>optimal</span> <span style=''>under</span> <span style=''>zero</span> <span style=''>one</span> <span style=''>loss</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>parity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>strictly</span> <span style=''>subsumes</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>based</span> <span style=''>model</span> <span style=''>families</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>EVMs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SVMs</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>which</span> <span style=''>a ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Preference</span> <span style=''>Learning</span> <span style=''>Toolbox</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Preference</span> <span style=''>learning</span> <span style=''>(PL)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>core</span> <span style=''>area</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>that</span> <span style=''>handles</span> <span style=''>datasets</span> <span style=''>with</span> <span style=''>ordinal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>As</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>data</span> <span style=''>of</span> <span style=''>ordinal</span> <span style=''>nature</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>and</span> <span style=''>role</span> <span style=''>of</span> <span style=''>the</span> <span style=''>PL</span> <span style=''>field</span> <span style=''>becomes</span> <span style=''>central</span> <span style=''>within</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>research</span> <span style=''>and</span> <span style=''>practice</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accessible</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preference</span> <span style=''>learning</span> <span style=''>toolbox</span> <span style=''>that</span> <span style=''>supports</span> <span style=''>the</span> <span style=''>key</span> <span style=''>phases</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>training</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>various</span> <span style=''>popular</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preprocessing</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preference</span> <span style=''>learning</span> <span style=''>methods</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12651894210150108)
# 	architecture (0.08863473909935668)
# 	representation (0.139385275196569)
# 	segmentation (0.06719085060757685)
# 	information (0.24767691208005718)
# 	experimental (0.1390278770550393)
# 	detection (0.11651179413867048)
# 	different (0.2694781987133667)
# 	recognition (0.1322373123659757)
# 	convolutional (0.13688348820586133)
#
# Some Statistics words are:
# 	variables (0.14235764235764237)
# 	theoretical (0.14935064935064934)
# 	stochastic (0.13436563436563437)
# 	statistical (0.15434565434565434)
# 	estimation (0.17382617382617382)
# 	distribution (0.1813186813186813)
# 	algorithm (0.38961038961038963)
# 	inference (0.2062937062937063)
# 	dimensional (0.1913086913086913)
# 	regression (0.17432567432567433)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7dcb5372-7a13-4dca-b0bf-77513d5c21cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dcb5372-7a13-4dca-b0bf-77513d5c21cc")) {                    Plotly.newPlot(                        "7dcb5372-7a13-4dca-b0bf-77513d5c21cc",                        [{"x":["structure","regularization","algorithm","frobenius","application","reconstructing","approximation","bipartite","thresholding","minimization","incoherence","condition","conditions","independent","rescaling","computational","recovered","complexity","controlling","approximately","alternating","assumption","completion","hierarchical","efficiency","combination","experiments","arrangements","outperformed","sophisticated","algorithms","stochastically","restricted","simultaneous","conventional","difficult","constructing","restriction","metropolis","calculating","restaurant","developed","distributions","retaining","dirichlet","explosion","combinatorial","collapsed","representation","including","vocabularies","agreement","individuals","principle","emergence","linguistic","strategies","alignment","vocabulary","simulations","essentially","population","relations","conventions","communities","artificial","numerical","preliminary","dimensional","formation","communicative","languages","minimizes","identification","structures","robustness","simulated","established","grassmannian","drawbacks","forecasting","processing","initialization","evaluated","approaches","manifolds","structured","applications","factorization","underlying","architecture","reconstruction","arbitrary","discriminative","supervised","interpretable","reconstruct","challenges","connected","segmentation","unsupervised","enhancement","parameters","benchmark","classification","committee","interaction","inferring","arguments","primarily","generative","performance","evolution","capabilities","relationships","uncovering","demonstrating","discussions","multivariate","inference","discovers","influence","transcripts","extensive","coreference","different","resolution","improving","outperforms","embeddings","anaphoric","detecting","generalized","representations","discrepancy","important","facilitates","predicting","inpatient","medication","pharmacological","investigate","discharge","predictions","convolutional","technologies","physicians","demonstrate","information","documented","admission","unstructured","correlations","capturing","baselines","detection","available","procedure","represented","illustrated","implemented","microstructure","introduced","observation","frequency","simulation","estimation","estimator","estimated","multiscale","integrated","correlated","volatility","correction","simultaneously","geometries","searching","technique","estimating","optimizing","performed","representing","variability","stationarity","proposing","likelihood","importance","constrain","challenging","parametric","quantitative","qualitative","misleading","tailoring","aesthetics","behaviours","paintings","cooperation","mechanisms","intelligence","constraints","specification","autonomous","collective","representational","distributed","commitment","specified","behaviour","mechanism","particular","symbiotic","corresponds","misclassification","predictors","resulting","surrogates","qualitatively","carefully","minimizing","predictor","surrogate","functions","degeneracy","significant","theoretical","sufficient","perspective","hypothesis","hypotheses","optimization","converging","evaluation","understood","development","understanding","empirical","validated","effective","experimental","promising","published","nonetheless","exploration","asymptotic","statistical","maintains","criticized","coefficient","variables","functional","statistics","calculated","motivates","increase ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	rescaling
# 	criticized
# 	equitability
# 	underpowered
# 	combinatorially
# 	datapoints
# 	diagonalise
# 	stagewise
# 	frequentist
# 	statisticians
# 	confounding
# 	uncontaminated
# 	individualized
# 	universally
# 	misspecification
# 	pertinent
# 	recidivism
# 	understandings
# 	correntropy
# 	randomforest
# Some words which never appear in Statistics papers:
# 	conventions
# 	communicative
# 	coreference
# 	anaphoric
# 	admission
# 	aesthetics
# 	paintings
# 	commitment
# 	symbiotic
# 	educators
# 	steganographic
# 	divisible
# 	steganography
# 	newspapers
# 	metaheuristic
# 	ultrasound
# 	morphemes
# 	programmed
# 	photometric
# 	concatenating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.071064430931761e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
